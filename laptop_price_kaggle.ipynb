# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import csv
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
laptopPrice_df= pd.read_csv('laptop_data_cleaned.csv',)
laptopPrice_df=laptopPrice_df.sort_index()
laptopPrice_df.head()
# Out:
#   Company   TypeName  Ram  Weight      Price  TouchScreen  Ips         Ppi  \
# 0   Apple  Ultrabook    8    1.37  11.175755            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34  10.776777            0    0  127.677940
# 2      HP   Notebook    8    1.86  10.329931            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  11.814476            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37  11.473101            0    1  226.983005
#
#        Cpu_brand  HDD  SSD Gpu_brand      Os
# 0  Intel Core i5    0  128     Intel     Mac
# 1  Intel Core i5    0    0     Intel     Mac
# 2  Intel Core i5    0  256     Intel  Others
# 3  Intel Core i7    0  512       AMD     Mac
# 4  Intel Core i5    0  256     Intel     Mac

# %%
Number_of_Brand=laptopPrice_df['Company'].value_counts()
#List_of_Brand=laptopPrice_df['Company'].tolist()
List_of_Brand=list(set(laptopPrice_df['Company']))
print(Number_of_Brand)
print(List_of_Brand)
len(List_of_Brand)
# Out:
# Dell         291
# Lenovo       289
# HP           268
# Asus         151
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        8
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# LG             3
# Google         3
# Chuwi          3
# Fujitsu        3
# Huawei         2
# Name: Company, dtype: int64
# ['Xiaomi', 'Asus', 'Dell', 'Acer', 'Apple', 'Chuwi', 'Razer', 'Samsung', 'Huawei', 'Vero', 'Mediacom', 'LG', 'MSI', 'HP', 'Google', 'Microsoft', 'Lenovo', 'Fujitsu', 'Toshiba']
# 19

# %%
#Example of loc 
#AcerPrice_df=laptopPrice_df.loc["Acer"]
AcerPrice_df=laptopPrice_df.loc[laptopPrice_df["Company"]=="Acer"]
AcerPrice_df
# Out:
#      Company            TypeName  Ram  Weight      Price  TouchScreen  Ips  \
# 5       Acer            Notebook    4     2.1   9.967026            0    0
# 9       Acer           Ultrabook    8     1.6  10.621952            0    1
# 36      Acer            Notebook    4     2.1   9.880923            0    0
# 43      Acer            Notebook    4     2.2  10.500591            0    1
# 51      Acer            Notebook    8     2.2  10.710153            0    1
# ...      ...                 ...  ...     ...        ...          ...  ...
# 1214    Acer             Netbook    2     1.3   9.134616            0    0
# 1215    Acer            Notebook    4     3.3  10.369152            0    0
# 1218    Acer  2 in 1 Convertible    8     1.2  11.022208            1    1
# 1241    Acer            Notebook    4     2.4   9.866653            0    0
# 1262    Acer            Notebook    4     2.4   9.641988            0    0
#
# ...

# %%
# Dta Frame with Price and Type
#laptopPrice_df=laptopPrice_df.reset_index()
PriceType_df=pd.DataFrame({"Company":laptopPrice_df["Company"], "TypeName": laptopPrice_df["TypeName"], "Price": laptopPrice_df["Price"], "Screen":  laptopPrice_df["Ppi"]})
PriceType_df
#laptopPrice_df["Company"].info()
# Out:
#      Company            TypeName      Price      Screen
# 0      Apple           Ultrabook  11.175755  226.983005
# 1      Apple           Ultrabook  10.776777  127.677940
# 2         HP            Notebook  10.329931  141.211998
# 3      Apple           Ultrabook  11.814476  220.534624
# 4      Apple           Ultrabook  11.473101  226.983005
# ...      ...                 ...        ...         ...
# 1268    Asus            Notebook  10.555257  100.454670
# 1269  Lenovo  2 in 1 Convertible  10.433899  157.350512
# 1270  Lenovo  2 in 1 Convertible  11.288115  276.053530
# 1271  Lenovo            Notebook   9.409283  111.935204
# 1272      HP            Notebook  10.614129  100.454670
#
# [1273 rows x 4 columns]

# %%
#correlation between weight and price
plt.figure(figsize=(10, 10))

plt.scatter(laptopPrice_df["Price"],laptopPrice_df["Weight"])

# %%
#correlation between company and weight
plt.figure()

laptopPrice_df.boxplot(column='Weight', by='Company', figsize=(20, 10))
# Out:
# <AxesSubplot:title={'center':'Weight'}, xlabel='Company'>

# %%
BrandName=list(PriceType_df["Company"])
TypeName= list(PriceType_df["TypeName"])
Price = list(laptopPrice_df["Price"])

plt.figure(figsize=(20, 16))
#plt.bar(TypeName, Price, width = 0.2)

plot=PriceType_df.boxplot(column='Price', by='Company', figsize=(20, 16))
#plt.show()
Typeplot=PriceType_df.boxplot(column='Price', by='TypeName', figsize=(20, 16))

# %%
#laptopPrice_df=laptopPrice_df.reset_index()

# Get unique values from a specific column
#unique_values = laptopPrice_df['Company'].unique()
#unique_values = laptopPrice_df.index.unique()

# Dictionary to store the dynamically created DataFrames
#dfs = {}
#variables = {}
#variables_list=[]

#for value in unique_values:
    # Filter original DataFrame based on unique value
    #filtered_df = original_df[original_df['Name'] == value]
    #filtered_df = laptopPrice_df[laptopPrice_df['Company']== value]
#    filtered_df = laptopPrice_df[laptopPrice_df.index == value]
    # Create a new DataFrame using the filtered data
#    dfs[value] = pd.DataFrame(filtered_df)
    
#for key, df in dfs.items():
    #print(f"DataFrame for {key}:")
    #print(df)
    #print()
#    for y in List_of_Brand:
#        variable_name = f"var_{y}"
#        variable_value = df
#        variables[variable_name] = variable_value
#        locals()[variable_name] = variable_value
        #print(variable_name)
        
var_Dell

# %%
# Chatgpt code (modified) to create multiple data frame from a list
#df_list= []

#for i in List_of_Brand:
#    df_val=f"DataFrame_{i}"
#    df_list.append(df_val)
    #print(f"DataFrame {i}:")
    
#print(df_list)

#laptopPrice_df=laptopPrice_df.reset_index()

#for C in laptopPrice_df["Company"]:
#    if C == List_of_Brand;
#    exec(f"{C} = {variable_value}")

# Create DataFrames using the list of data
#for data in data_list:
#    df = pd.DataFrame(data)
#    df_list.append(df)

# Access the created DataFrames
#for i, df in enumerate(df_list):
#    print(f"DataFrame {i+1}:")
 #   print(df)
  #  print()
